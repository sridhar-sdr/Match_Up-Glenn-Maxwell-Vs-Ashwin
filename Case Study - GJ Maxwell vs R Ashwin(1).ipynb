# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

#to display all rows columns 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
# ipl_ball_by_ball_data

# %%
df = pd.read_csv('ipl_ball_by_ball_updated.csv')

# %%
df.head(1)
# Out:
#    match_id  season  start_date                  venue  innings  ball                 batting_team           bowling_team     striker non_striker      bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0  335982    2008    2008-04-18  M Chinnaswamy Stadium  2        6.8   Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher  CL White    AB Agarkar  4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN

# %%
df.innings.unique()
# Out:
# array([2, 1, 4, 3, 6, 5], dtype=int64)

# %%
df = df[(df.innings == 1) | (df.innings == 2)]

# %%
df.innings.unique()
# Out:
# array([2, 1], dtype=int64)

# %%
# What are the numbers when Maxwell faces Ashwin?
# step 1: Filter by player names - Done
# step 2: Use these names & assign it to striker & bowler - Done
# step 3: Get the required columns - Done

# %%
df.bowling_team.unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings'],
#       dtype=object)

# %%
df[df.bowling_team == 'Chennai Super Kings']['bowler'].unique()
# Out:
# array(['JDP Oram', 'Joginder Sharma', 'M Muralitharan', 'P Amarnath',
#        'MS Gony', 'JA Morkel', 'M Ntini', 'S Vidyut', 'SK Raina',
#        'L Balaji', 'CK Kapugedera', 'A Flintoff', 'T Thushara', 'S Tyagi',
#        'SB Jakati', 'R Ashwin', 'JM Kemp', 'NLTC Perera', 'C Ganapathy',
#        'DE Bollinger', 'S Randiv', 'TG Southee', 'SB Styris',
#        'KMDN Kulasekara', 'DJ Bravo', 'RA Jadeja', 'F du Plessis',
#        'VY Mahesh', 'BW Hilfenhaus', 'B Laughlin', 'DP Nannes',
#        'AS Rajpoot', 'CH Morris', 'MM Sharma', 'JO Holder', 'A Nehra',
#        'P Negi', 'DR Smith', 'IC Pandey', 'S Badree', 'V Shankar',
#        'DJ Hussey', 'JW Hastings', 'RG More', 'SR Watson',
#        'Harbhajan Singh', 'MA Wood', 'DL Chahar', 'Imran Tahir',
#        'SN Thakur', 'KV Sharma', 'L Ngidi', 'KM Asif', 'DJ Willey',
#        'MJ Santner', 'SC Kuggeleijn', 'PP Chawla', 'SM Curran',
#        'JR Hazlewood', 'Monu Kumar', 'MM Ali'], dtype=object)

# %%
# player 1: R Ashwin
# player 2: Maxwell

# %%
df[df.batting_team == 'Kings XI Punjab']['striker'].unique()
# Out:
# array(['SM Katich', 'IK Pathan', 'KC Sangakkara', 'Yuvraj Singh',
#        'JR Hopes', 'K Goel', 'PP Chawla', 'DPMD Jayawardene', 'S Sohal',
#        'B Lee', 'WA Mota', 'S Sreesanth', 'VRV Singh', 'RR Sarwan',
#        'TM Srivastava', 'SE Marsh', 'U Kaul', 'LA Pomersbach', 'RR Powar',
#        'RS Bopara', 'T Kohli', 'M Kaif', 'MS Bisla', 'YA Abdulla',
#        'Bipul Sharma', 'AB Barath', 'J Theron', 'SJ Srivastava',
#        'VS Malik', 'RS Sodhi', 'R McLaren', 'AM Nayar', 'KD Karthik',
#        'PC Valthaty', 'AC Gilchrist', 'Sunny Singh', 'NJ Rimmington',
#        'P Kumar', 'RJ Harris', 'DJ Hussey', 'L Ablish', 'Mandeep Singh',
#        'SD Chitnis', 'BA Bhatt', 'JP Faulkner', 'Harmeet Singh',
#        'AD Mascarenhas', 'P Dogra', 'N Saini', 'DA Miller',
#        'Azhar Mahmood', 'Gurkeerat Singh', 'P Awana', 'M Vohra',
#        'R Sathish', 'MS Gony', 'Sandeep Sharma', 'V Sehwag', 'CA Pujara',
#        'GJ Maxwell', 'AR Patel', 'GJ Bailey', 'WP Saha', 'MG Johnson',
#        'R Dhawan', 'L Balaji', 'Shivam Sharma', 'BE Hendricks',
#        'Karanveer Singh', 'Anureet Singh', 'M Vijay', 'NLTC Perera',
#        'SN Thakur', 'MP Stoinis', 'MM Sharma', 'P Sahu', 'KJ Abbott',
#        'NS Naik', 'KC Cariappa', 'Swapnil Singh', 'HM Amla',
#        'F Behardien', 'VR Aaron', 'EJG Morgan', 'I Sharma', 'MJ Guptill',
#        'R Tewatia', 'KK Nair', 'MA Agarwal', 'KL Rahul',
#        'Mujeeb Ur Rahman', 'AJ Finch', 'R Ashwin', 'AJ Tye', 'CH Gayle',
#        'BB Sran', 'MK Tiwary', 'AS Rajpoot', 'AD Nath', 'SN Khan',
#        'N Pooran', 'Mohammed Shami', 'SM Curran', 'GC Viljoen',
#        'M Ashwin', 'Harpreet Brar', 'P Simran Singh', 'CJ Jordan',
#        'K Gowtham', 'JDS Neesham', 'Ravi Bishnoi', 'Arshdeep Singh',
#        'SS Cottrell', 'DJ Hooda'], dtype=object)

# %%
req_df = df[(df.striker == 'GJ Maxwell') & (df.bowler == 'R Ashwin')]

# %%
req_df.head()
# Out:
#        match_id  season  start_date                 venue  innings  ball     batting_team         bowling_team     striker non_striker    bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 95256  729283    2014    2014-04-18  Sheikh Zayed Stadium  2        10.6  Kings XI Punjab  Chennai Super Kings  GJ Maxwell  DA Miller   R Ashwin  4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 95258  729283    2014    2014-04-18  Sheikh Zayed Stadium  2        10.3  Kings XI Punjab  Chennai Super Kings  GJ Maxwell  DA Miller   R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 95259  729283    2014    2014-04-18  Sheikh Zayed Stadium  2        10.2  Kings XI Punjab  Chennai Super Kings  GJ Maxwell  DA Miller   R Ashwin  2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 95265  729283    2014    2014-04-18  Sheikh Zayed Stadium  2        10.5  Kings XI Punjab  Chennai Super Kings  GJ Maxwell  DA Miller   R Ashwin  2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 95274  729283    2014    2014-04-18  Sheikh Zayed Stadium  2        14.7  Kings XI Punjab  Chennai Super Kings  GJ Maxwell  DA Miller   R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN

# %%
# No of runs scored?
# No of balls faced?
# No of times dismissed?

# %%
# runs scored
sum(req_df.runs_off_bat)
# Out:
# 91

# %%
# balls faced
len(req_df)
# Out:
# 49

# %%
# outs
len(req_df[req_df.player_dismissed == 'GJ Maxwell'])
# Out:
# 1

# %%
res_df = df[(df.striker == 'CH Gayle') & (df.bowler == 'R Ashwin')]

# %%
res_df
# Out:
#         match_id  season  start_date                                venue  innings  ball                 batting_team         bowling_team   striker     non_striker    bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 38349   419153    2010    2010-04-13  MA Chidambaram Stadium, Chepauk      1        0.6   Kolkata Knight Riders        Chennai Super Kings  CH Gayle  SC Ganguly      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 38351   419153    2010    2010-04-13  MA Chidambaram Stadium, Chepauk      1        0.4   Kolkata Knight Riders        Chennai Super Kings  CH Gayle  SC Ganguly      R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 38374   419153    2010    2010-04-13  MA Chidambaram Stadium, Chepauk      1        2.2   Kolkata Knight Riders        Chennai Super Kings  CH Gayle  SC Ganguly      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       stumped     CH Gayle        NaN                NaN
# 38400   419153    2010    2010-04-13  MA Chidambaram Stadium, Chepauk      1        2.1   Kolkata Knight Riders        Chennai Super Kings  CH Gayle  SC Ganguly      R Ashwin  6             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57569   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        2.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57570   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        2.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57571   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        2.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57572   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        2.1   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57579   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        0.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57591   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        4.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57593   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        4.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57605   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        6.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57608   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        6.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57610   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        6.1   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57615   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        6.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57617   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        4.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57618   501266    2011    2011-05-22  M Chinnaswamy Stadium                2        4.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57796   501268    2011    2011-05-24  Wankhede Stadium                     1        3.1   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57797   501268    2011    2011-05-24  Wankhede Stadium                     1        3.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  6             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 57798   501268    2011    2011-05-24  Wankhede Stadium                     1        3.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       lbw         CH Gayle        NaN                NaN
# 58393   501271    2011    2011-05-28  MA Chidambaram Stadium, Chepauk      2        0.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 58394   501271    2011    2011-05-28  MA Chidambaram Stadium, Chepauk      2        0.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       caught      CH Gayle        NaN                NaN
# 58421   501271    2011    2011-05-28  MA Chidambaram Stadium, Chepauk      2        0.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 61668   548318    2012    2012-04-12  MA Chidambaram Stadium, Chepauk      1        15.5  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 61669   548318    2012    2012-04-12  MA Chidambaram Stadium, Chepauk      1        15.4  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 61672   548318    2012    2012-04-12  MA Chidambaram Stadium, Chepauk      1        15.1  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 61696   548318    2012    2012-04-12  MA Chidambaram Stadium, Chepauk      1        4.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 61704   548318    2012    2012-04-12  MA Chidambaram Stadium, Chepauk      1        0.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 61705   548318    2012    2012-04-12  MA Chidambaram Stadium, Chepauk      1        0.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 61706   548318    2012    2012-04-12  MA Chidambaram Stadium, Chepauk      1        0.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  MA Agarwal      R Ashwin  2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 92768   598068    2013    2013-05-18  M Chinnaswamy Stadium                1        0.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 92769   598068    2013    2013-05-18  M Chinnaswamy Stadium                1        0.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 92886   598068    2013    2013-05-18  M Chinnaswamy Stadium                1        2.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             1      NaN    NaN      NaN    1.0     NaN       NaN         NaN             NaN                NaN
# 104462  734013    2014    2014-05-18  JSCA International Stadium Complex   2        1.1   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  PA Patel        R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104463  734013    2014    2014-05-18  JSCA International Stadium Complex   2        1.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  PA Patel        R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104491  734013    2014    2014-05-18  JSCA International Stadium Complex   2        5.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104499  734013    2014    2014-05-18  JSCA International Stadium Complex   2        5.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104510  734013    2014    2014-05-18  JSCA International Stadium Complex   2        5.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104511  734013    2014    2014-05-18  JSCA International Stadium Complex   2        5.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104512  734013    2014    2014-05-18  JSCA International Stadium Complex   2        5.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104523  734013    2014    2014-05-18  JSCA International Stadium Complex   2        3.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104524  734013    2014    2014-05-18  JSCA International Stadium Complex   2        3.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104531  734013    2014    2014-05-18  JSCA International Stadium Complex   2        5.1   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104757  734013    2014    2014-05-18  JSCA International Stadium Complex   2        16.1  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  AB de Villiers  R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104758  734013    2014    2014-05-18  JSCA International Stadium Complex   2        16.2  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  AB de Villiers  R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 104784  734013    2014    2014-05-18  JSCA International Stadium Complex   2        16.6  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  AB de Villiers  R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       bowled      CH Gayle        NaN                NaN
# 104786  734013    2014    2014-05-18  JSCA International Stadium Complex   2        16.5  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  AB de Villiers  R Ashwin  6             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122139  829821    2015    2015-05-22  JSCA International Stadium Complex   1        3.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122140  829821    2015    2015-05-22  JSCA International Stadium Complex   1        3.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122147  829821    2015    2015-05-22  JSCA International Stadium Complex   1        5.1   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  Mandeep Singh   R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122148  829821    2015    2015-05-22  JSCA International Stadium Complex   1        5.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  Mandeep Singh   R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122151  829821    2015    2015-05-22  JSCA International Stadium Complex   1        3.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122167  829821    2015    2015-05-22  JSCA International Stadium Complex   1        3.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122168  829821    2015    2015-05-22  JSCA International Stadium Complex   1        3.1   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122184  829821    2015    2015-05-22  JSCA International Stadium Complex   1        1.2   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122185  829821    2015    2015-05-22  JSCA International Stadium Complex   1        1.3   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122186  829821    2015    2015-05-22  JSCA International Stadium Complex   1        1.4   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122187  829821    2015    2015-05-22  JSCA International Stadium Complex   1        1.5   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 122188  829821    2015    2015-05-22  JSCA International Stadium Complex   1        1.6   Royal Challengers Bangalore  Chennai Super Kings  CH Gayle  V Kohli         R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 188223  1216546   2020    2020-10-20  Dubai International Cricket Stadium  2        5.1   Kings XI Punjab              Delhi Capitals       CH Gayle  MA Agarwal      R Ashwin  2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 188224  1216546   2020    2020-10-20  Dubai International Cricket Stadium  2        5.2   Kings XI Punjab              Delhi Capitals       CH Gayle  MA Agarwal      R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       bowled      CH Gayle        NaN                NaN
# 195816  1254068   2021    2021-04-18  Wankhede Stadium, Mumbai             1        13.1  Punjab Kings                 Delhi Capitals       CH Gayle  KL Rahul        R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 195820  1254068   2021    2021-04-18  Wankhede Stadium, Mumbai             1        13.4  Punjab Kings                 Delhi Capitals       CH Gayle  KL Rahul        R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 195868  1254068   2021    2021-04-18  Wankhede Stadium, Mumbai             1        13.6  Punjab Kings                 Delhi Capitals       CH Gayle  KL Rahul        R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN

# %%
sum(res_df.runs_off_bat),len(res_df),len(res_df[res_df.player_dismissed == 'CH Gayle'])
# Out:
# (53, 64, 5)

# %%
# balls faced
rew_df = df[(df.striker == 'PA Patel') & (df.bowler == 'R Ashwin')]

# %%
sum(rew_df.runs_off_bat),len(rew_df),len(rew_df[rew_df.player_dismissed == 'PA Patel'])
# Out:
# (32, 46, 4)

# %%
gamb_df = df[(df.striker == 'G Gambhir') & (df.bowler == 'R Ashwin')]

# %%
sum(gamb_df.runs_off_bat),len(gamb_df),len(gamb_df[gamb_df.player_dismissed == 'G Gambhir'])
# Out:
# (52, 55, 2)

# %%
kock_df = df[(df.striker == 'Q de Kock') & (df.bowler == 'R Ashwin')]

# %%
sum(kock_df.runs_off_bat),len(kock_df),len(kock_df[kock_df.player_dismissed == 'Q de Kock'])
# Out:
# (76, 65, 4)

# %%
rana_df = df[(df.striker == 'N Rana') & (df.bowler == 'R Ashwin')]

# %%
sum(rana_df.runs_off_bat),len(rana_df),len(rana_df[rana_df.player_dismissed == 'N Rana'])
# Out:
# (74, 37, 0)

# %%
N Rana

# %%
# strike rate
100*sum(req_df.runs_off_bat)/len(req_df)
# Out:
# 185.71428571428572

# %%
# Comparision against all batsman Ashwin has bowled to

# %%
df.head(1)
# Out:
#    match_id  season  start_date                  venue  innings  ball                 batting_team           bowling_team     striker non_striker      bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0  335982    2008    2008-04-18  M Chinnaswamy Stadium  2        6.8   Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher  CL White    AB Agarkar  4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN

# %%
ashwin_df = df[df.bowler =='R Ashwin']

# %%
ashwin_df.head()
# Out:
#        match_id  season  start_date      venue  innings  ball     batting_team         bowling_team        striker    non_striker    bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 25519  392234    2009    2009-05-20  Kingsmead  2        9.4   Kings XI Punjab  Chennai Super Kings  Yuvraj Singh   LA Pomersbach  R Ashwin  0             1      NaN    NaN      NaN    1.0     NaN       NaN         NaN             NaN                NaN
# 25527  392234    2009    2009-05-20  Kingsmead  2        13.6  Kings XI Punjab  Chennai Super Kings  KC Sangakkara  WA Mota        R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 25528  392234    2009    2009-05-20  Kingsmead  2        13.5  Kings XI Punjab  Chennai Super Kings  WA Mota        KC Sangakkara  R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 25529  392234    2009    2009-05-20  Kingsmead  2        13.4  Kings XI Punjab  Chennai Super Kings  WA Mota        KC Sangakkara  R Ashwin  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 25530  392234    2009    2009-05-20  Kingsmead  2        13.3  Kings XI Punjab  Chennai Super Kings  KC Sangakkara  WA Mota        R Ashwin  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN

# %%
# runs scored by this batsman
bdf1 = pd.DataFrame(ashwin_df.groupby('striker')['runs_off_bat'].sum()).reset_index()

# %%
bdf2 = pd.DataFrame(ashwin_df.groupby('striker')['ball'].count()).reset_index()

# %%
bdf2.head()
# Out:
#           striker  ball
# 0  A Mishra        12
# 1  A Mithun        2
# 2  A Symonds       16
# 3  AB Agarkar      4
# 4  AB de Villiers  61

# %%
bdf3 = bdf1.merge(bdf2, on = 'striker', how = 'left')

# %%
bdf3.head(1)
# Out:
#     striker  runs_off_bat  ball
# 0  A Mishra  5             12

# %%
bdf3['strike_rate'] = 100*bdf3['runs_off_bat']/bdf3['ball']

# %%
bdf3.head(1)
# Out:
#     striker  runs_off_bat  ball  strike_rate
# 0  A Mishra  5             12    41.666667

# %%
# min criteria: 30 balls

# %%
bdf3 = bdf3[bdf3.ball >= 30]

# %%
bdf3.head(20)
# Out:
#            striker  runs_off_bat  ball  strike_rate
# 0   AB de Villiers  69            61    113.114754
# 1   AC Gilchrist    46            45    102.222222
# 2   AM Rahane       31            34    91.176471
# 3   AT Rayudu       88            81    108.641975
# 4   BB McCullum     29            41    70.731707
# 5   CH Gayle        53            64    82.812500
# 6   DA Miller       54            52    103.846154
# 7   DA Warner       95            89    106.741573
# 8   G Gambhir       52            55    94.545455
# 9   GJ Maxwell      91            49    185.714286
# 10  Ishan Kishan    40            41    97.560976
# 11  JC Buttler      33            33    100.000000
# 12  JH Kallis       36            40    90.000000
# 13  KA Pollard      54            39    138.461538
# 14  KD Karthik      55            50    110.000000
# 15  KS Williamson   58            42    138.095238
# 16  LMP Simmons     58            51    113.725490
# 17  M Vijay         28            31    90.322581
# 18  MA Agarwal      55            36    152.777778
# 19  MK Pandey       63            57    110.526316

# %%
abd_df = df[df.striker =='GJ Maxwell']

# %%
# runs scored by this batsman
adf1 = pd.DataFrame(abd_df.groupby('bowler')['runs_off_bat'].sum()).reset_index()

# %%
adf1.head()
# Out:
#       bowler  runs_off_bat
# 0  A Mishra   66
# 1  A Nehra    10
# 2  A Nortje   11
# 3  AA Chavan  16
# 4  AB Dinda   12

# %%
# balls faced
adf2 = pd.DataFrame(abd_df.groupby('bowler')['ball'].count()).reset_index()

# %%
adf2.head()
# Out:
#       bowler  ball
# 0  A Mishra   37
# 1  A Nehra    11
# 2  A Nortje   7
# 3  AA Chavan  10
# 4  AB Dinda   6

# %%
adf3 = adf1.merge(adf2, on = 'bowler', how = 'left')

# %%
adf3.head(1)
# Out:
#      bowler  runs_off_bat  ball
# 0  A Mishra  66            37

# %%
adf3['strike_rate'] = 100*adf3['runs_off_bat']/adf3['ball']

# %%
adf3.head()
# Out:
#             bowler  runs_off_bat  ball  strike_rate
# 0  A Mishra         66            37    178.378378
# 1  Harbhajan Singh  60            30    200.000000
# 2  JJ Bumrah        44            39    112.820513
# 3  KH Pandya        36            31    116.129032
# 4  PP Chawla        54            36    150.000000

# %%
# min criteria : 30 balls

# %%
adf3 = adf3[adf3.ball >= 30]

# %%
adf3.head()
# Out:
#             bowler  runs_off_bat  ball  strike_rate
# 0  A Mishra         66            37    178.378378
# 1  Harbhajan Singh  60            30    200.000000
# 2  JJ Bumrah        44            39    112.820513
# 3  KH Pandya        36            31    116.129032
# 4  PP Chawla        54            36    150.000000

# %%
data=adf3.sort_values('strike_rate', ascending = False)
data
# Out:
#             bowler  runs_off_bat  ball  strike_rate
# 1  Harbhajan Singh  60            30    200.000000
# 5  R Ashwin         91            49    185.714286
# 0  A Mishra         66            37    178.378378
# 4  PP Chawla        54            36    150.000000
# 7  RD Chahar        47            38    123.684211
# 6  RA Jadeja        43            36    119.444444
# 3  KH Pandya        36            31    116.129032
# 8  Rashid Khan      40            35    114.285714
# 2  JJ Bumrah        44            39    112.820513
# 9  SP Narine        58            57    101.754386

# %%
data.to_csv('maxwell vs all.csv',index=None)

# %%
# bdf3, adf3

# %%
bdf3.reset_index(inplace = True, drop = True)
adf3.reset_index(inplace = True, drop = True)

# %%
bdf3.head()
# Out:
#           striker  runs_off_bat  ball  strike_rate
# 0  AB de Villiers  69            61    113.114754
# 1  AC Gilchrist    46            45    102.222222
# 2  AM Rahane       31            34    91.176471
# 3  AT Rayudu       88            81    108.641975
# 4  BB McCullum     29            41    70.731707

# %%
bdf3.sort_values('strike_rate', ascending = False)
# Out:
#            striker  runs_off_bat  ball  strike_rate
# 20  N Rana          74            37    200.000000
# 9   GJ Maxwell      91            49    185.714286
# 29  SR Watson       76            49    155.102041
# 18  MA Agarwal      55            36    152.777778
# 34  YK Pathan       56            40    140.000000
# 26  SA Yadav        93            67    138.805970
# 13  KA Pollard      54            39    138.461538
# 15  KS Williamson   58            42    138.095238
# 32  Shubman Gill    46            34    135.294118
# 24  RV Uthappa      123           96    128.125000
# 33  V Kohli         160           131   122.137405
# 28  SR Tendulkar    39            32    121.875000
# 31  SV Samson       55            46    119.565217
# 22  Q de Kock       76            65    116.923077
# 16  LMP Simmons     58            51    113.725490
# 0   AB de Villiers  69            61    113.114754
# 19  MK Pandey       63            57    110.526316
# 14  KD Karthik      55            50    110.000000
# 3   AT Rayudu       88            81    108.641975
# 30  SS Iyer         44            41    107.317073
# 7   DA Warner       95            89    106.741573
# 6   DA Miller       54            52    103.846154
# 1   AC Gilchrist    46            45    102.222222
# 11  JC Buttler      33            33    100.000000
# 27  SK Raina        54            55    98.181818
# 10  Ishan Kishan    40            41    97.560976
# 8   G Gambhir       52            55    94.545455
# 35  Yuvraj Singh    45            48    93.750000
# 2   AM Rahane       31            34    91.176471
# 23  RG Sharma       105           116   90.517241
# 17  M Vijay         28            31    90.322581
# 12  JH Kallis       36            40    90.000000
# 5   CH Gayle        53            64    82.812500
# 25  S Dhawan        71            90    78.888889
# 4   BB McCullum     29            41    70.731707
# 21  PA Patel        32            46    69.565217

# %%
adf3.sort_values('strike_rate', ascending = False)
# Out:
#             bowler  runs_off_bat  ball  strike_rate
# 1  Harbhajan Singh  60            30    200.000000
# 5  R Ashwin         91            49    185.714286
# 0  A Mishra         66            37    178.378378
# 4  PP Chawla        54            36    150.000000
# 7  RD Chahar        47            38    123.684211
# 6  RA Jadeja        43            36    119.444444
# 3  KH Pandya        36            31    116.129032
# 8  Rashid Khan      40            35    114.285714
# 2  JJ Bumrah        44            39    112.820513
# 9  SP Narine        58            57    101.754386

# %%
plt.figure(figsize = (16, 8))
plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)

for i in range(len(bdf3)):
#     plt.text(x, y, text)
    if bdf3['striker'][i] == 'GJ Maxwell':
        plt.text(bdf3['strike_rate'][i] - 7, bdf3['runs_off_bat'][i] - 1, bdf3['striker'][i] )
    else:
        plt.text(bdf3['strike_rate'][i] + 1, bdf3['runs_off_bat'][i] - 1, bdf3['striker'][i] )

plt.axvline(120, ls = '--', color = 'grey')
plt.axhline(60, ls = '--', color = 'grey')
plt.title('Batsman against R ashwin in IPL (min 30 balls faced)', fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.rcParams['axes.facecolor'] = '#fff7fb'
plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)

for i in range(len(bdf3)):
    if bdf3.striker[i] == 'V Kohli':
        plt.text(bdf3.strike_rate[i] - 7, bdf3.runs_off_bat[i] - 1, bdf3.striker[i])
    elif bdf3.striker[i] == 'GJ Maxwell':
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i], color = 'maroon')
    elif (bdf3.striker[i] == 'N Rana') | (bdf3.striker[i] == 'KL Rahul') | (bdf3.striker[i] == 'JP Duminy'):
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i])

plt.axvline(120, ls = '--', color = 'grey')
plt.axhline(60, ls = '--', color = 'grey')
plt.title("Best Batsman against R Ashwin", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Chart_ABD_vs_Bumrah_part1.jpg')
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.rcParams['axes.facecolor'] = '#fff7fb'
plt.scatter(adf3.strike_rate, adf3.runs_off_bat)

for i in range(len(adf3)):
    if adf3.bowler[i] == 'R Ashwin':
        plt.text(adf3.strike_rate[i] + 2, adf3.runs_off_bat[i] - 1, adf3.bowler[i], color = 'maroon')
    elif (adf3.bowler[i] == 'RA Jadeja') | (adf3.bowler[i] == 'A Mishra') | (adf3.bowler[i] == 'PP Chawla') | (adf3.bowler[i] == 'Harbhajan Singh'):
        plt.text(adf3.strike_rate[i] + 2, adf3.runs_off_bat[i] - 1, adf3.bowler[i])
    elif (adf3.bowler[i] == 'SP Narine'):
        plt.text(adf3.strike_rate[i], adf3.runs_off_bat[i] + 2, adf3.bowler[i],color = 'maroon')
    elif (adf3.bowler[i] == 'Rashid Khan'):
        plt.text(adf3.strike_rate[i] - 3, adf3.runs_off_bat[i] - 3, adf3.bowler[i])

plt.axvline(110, ls = '--', color = 'grey')
plt.axhline(80, ls = '--', color = 'grey')
plt.title("Maxwell's Favorite Bowlers", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Chart_Maxwell_vs_Ashwin_part2.jpg')
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.rcParams['axes.facecolor'] = '#fff7fb'
plt.scatter(bdf3.strike_rate, bdf3.runs_off_bat)

for i in range(len(bdf3)):
    if bdf3.striker[i] == 'PA Patel':
        plt.text(bdf3.strike_rate[i] - 7, bdf3.runs_off_bat[i] - 1, bdf3.striker[i])
    elif bdf3.striker[i] == 'BB McCullum':
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i], color = 'maroon')
    elif (bdf3.striker[i] == 'S Dhawan') | (bdf3.striker[i] == 'CH Gayle') | (bdf3.striker[i] == 'DA Warner'):
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i],color = 'maroon')
    elif (bdf3.striker[i] == 'DA Miller') | (bdf3.striker[i] == 'G Gambhir') | (bdf3.striker[i] == 'Yuvraj Singh'):
        plt.text(bdf3.strike_rate[i] + 2, bdf3.runs_off_bat[i] - 1, bdf3.striker[i],color = 'maroon')

plt.axvline(110, ls = '--', color = 'grey')
plt.axhline(60, ls = '--', color = 'grey')
plt.title(" R Ashwin's Favourite batsman", fontsize = 20)
plt.xlabel('Strike rate')
plt.ylabel('Runs scored')
plt.savefig('Chart_ABD_vs_Bumrah_part1.jpg')
plt.show()

# %%
d=bdf3.sort_values('strike_rate', ascending = True)

# %%
d.to_csv('Data_with_str.csv',index=None)
